# %% [markdown]
# # 1. Prediction of Crime Rates using Socioeconomic Factors within Cleveland

# %% [markdown]
# # TODO checklist
# -[ ] (optional) matching up combined/split tracts
# - [ ] Dictionary to assign 2020 tracts to   2010 tracts ids
#     - [ ] Download csv of ALL the census data for our variables
#         - [ ] healthcare variables
# - [ ] Geoenrichment to create number of violent crimes per census tract
#     - [ ] Merge crime data with census variables data
#
# - [ ] Perform correlation analysis to figure out which factors play the biggest roles in crime
# - [ ] Train various machine learning models

# %% [markdown]
# # 2. Team Members
# * Calvin Nguyen, A16934418
# * Ethan Cota, A18141093

# %% [markdown]
# # 3. Questions(s) we addressed, why is it important

# %% [markdown]
# We propose that we can find a correlation between socioeconomic factors and variables in the Census tract and the frequency and area of crimes occurring in the City of Cleveland. We believe this kind of project is a step towards creating dashboards and overviews on crime that can be helpful for police, or other public departments. We will explore potential answers to this problem by trying different machine learning models, spatial analysis techniques, or features to find trends in the frequency or location of the crimes occurring. Literature suggests that household income and employment are large indicators of an area being higher in crime, and there are studies that suggest a few other variables we can start to look for patterns within our data. One project that utilizes a linear regression model to predict crime outcomes found a small correlation between crime and socioeconomic factors. Through exploring this hypothesis we expect to reach similar findings and enhance accessible information specifically in this city. Utilizing features that have already been suggested to have correlation with crime and exploring existing analyses will be helpful for our process.
#
# The audience for this project would be the City of Cleveland, its public departments and also residents. This could be an informative map for people to have open access to information in their area, and also helpful for decision-making among police or policy makers. It is especially helpful and more powerful for viewers to see a conclusion or trend based on a visualization or something they can actually interact with, and would be very helpful in providing additional resources on the causes of crime in Cleveland.

# %% [markdown]
# # 4. Background and Literature

# %% [markdown]
# There are several studies related to this, but they often only focus on 1 or 2 socioeconomic factors. For example, we have a study from Sariaslan that studies how childhood family income affects violent criminality and substance misuse in Sweden. They found that children in the lowest income quintile had a 7 fold increase in criminality compared to peers in the highest quintile. Though this study does do analysis, it does not do spatial analysis. We do expect income will have a big factor in determining crime in a specific block. One study that does integrate spatial analysis in a particular city is from the University of Minnesota where they study socioeconomic status and demographic variables to crime in Pittsburgh. Here, they analyze census tract data from 1990 to 2001. They utilize multiple spatial analysis techniques through EDA. They used choropleth mapping to visualize crime across census tracts. Additionally, they used hotspot analysis to identify clusters of high and low crime areas. They also had to perform boundary reconciliation since they used two different years of census that had different boundaries. In terms of a model, they used a stepwise multiple linear regression. Using just socioeconomic factors, they were able to explain 21.1% of the variation in violent crime, with unemployment and household income as key predictors.  For our project, we will perform similar steps for the EDA to find potentially important features. We will use multi-step linear regression, but also other complex  models, such as kernel density estimation, to see whether they will result in lower loss. We will also include more socioeconomic and demographic variables, as we want to explain more of the variation.
# https://pmc.ncbi.nlm.nih.gov/articles/PMC4180846/
# https://gis.smumn.edu/GradProjects/MitchellS.pdf

# %% [markdown]
# # 5. Python packages you used and why?

# %% [markdown]
# Python
# * pandas: ETL, processing data from CSVs
# * geopandas: Prototype visualizations for crimes and EDA
# (building out ArcGIS visualizations is slow)
#     * shapely: Manage spatial data
# * scikit-learn: machine learning models
#     * DBSCAN or Isolation forest (determine clustering of concurrent crime)
# * pytorch: build autoencoders for anomaly detection (determine when there is an anomaly in terms of calls)
#
# ArcGIS
# * arcgis. …
#     * gis: Retrieve content, ArcGIS Online login/validation
#     * features: Transform pandas dataframes to geoaccessors and then into feature layers
#     * network: Connect networks of 911 calls (may prove useful later with ML)
#     * geocoding: Geocode locations of mass shootings/killings to coordinates
#     * geoenrichment: Gather regional statistics to help with analysis
#     * map: Generate interactive maps to compare location of  blocks and crime
#
# From our old proposal, we did use all of the features, except networks and geocoding. Our data already located precise locations of crimes, so it was not needed. However, we did have to add an additional number of packages. We have to use **analyze_data** and **manage_data** in order to perform hotspot analysis in ArcGIS. This allows us to get visualizations on whether certain socioeconomic factors are spatially correlated with crime

# %% [markdown]
# # 6. Data sources

# %% [markdown]
# # TODO
# - Add info about healthcare data here
# - Finish information on

# %% [markdown]
# We used only two data sources for this project.
# 1. The first is a dataset of [Crime Incidents occuring in Cleaveland, Ohio](https://data.clevelandohio.gov/datasets/ClevelandGIS::crime-incidents/about). This data is comprehensive coverage of all police arrest records occuring in 2016 or later.
# 2. Our other dataset is 5-year estimates from [American Community Survey Data](https://www.census.gov/programs-surveys/acs/data.html) (ACS5). This data represents tract-level information on Census variables.
# <br></br>
#
# &emsp;We had originally planned to use ACS1 data, because it would give us better insight into how the variables we are studying are changing from year to year. However because ACS1 data is not collected at the tract level, we had to use ACS5. Because we are already dealing with a small area of analysis and we are studying across 9-10 years of data, we decided to change to ACS 5 to preserve the spatial resolution of analysis we wanted to perform.
# &emsp; There are a significant number of variables we had could choose from the U.S. Census, from our proposal we wanted to look mostly at economic and housing characteristics. These included things such as levels of income, the Gini income inequality index, levels of education, types of household family structure, and access to health insurance.
# &emsp; Regarding our analysis on the dataset of crimes occuring, #TODO#
# - URL and a one-sentence description of each source you used
# - reflection on how your choice of sources evolved since  proposal
#     - and any concerns about the sources you used - related to data quality, provenance, access constraints, etc. Also, reflect on any data that would be helpful to address your research question, which you could not obtain (and why). Be creative! There is a lot of additional information, sometimes from less traditional sources, that may help.
# When you create a notebook, identify and describe the datasets as you load them. If the sources are in AGOL, provide source IDs, and/or load them using gis.content.get. Provide additional discussion in a markdown cell.

# %% [markdown]
# # 7. Data Cleaning you have done

# %% [markdown]
# We used

# %% [markdown]
# # 8. Descriptive statistics for the data

# %% [markdown]
# # 9. Analysis

# %% [markdown]
# # 10. Summary of products and results

# %% [markdown]
# # 11. Discussion

# %% [markdown]
# # 12. Conclusions and future work
